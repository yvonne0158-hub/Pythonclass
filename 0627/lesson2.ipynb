# %%
import matplotlib.pyplot as plt

labels = ['Nokia', 'Samsung', 'Apple', 'Lumia']
values = [20, 30, 45, 10]
colors = ['yellow', 'green', 'red', 'blue']

figure = plt.figure()
axes = figure.add_subplot()
axes.pie(values, #每個扇區的數值資料（list / array）
         labels=labels, #每個扇區的標籤文字
         colors=colors, #每個扇區的自訂顏色
         explode=[0.3, 0, 0, 0], #將第一個扇區「拉出」0.3 倍半徑距離，用來強調某個區塊
         shadow=True, #	在圓餅圖後方加上陰影，增加立體感
         autopct="%2.1f%%", #在扇區內部顯示百分比，格式為整數 2 位、小數 1 位（如 12.3%）
         startangle=180) #	第一個扇區的起始角度（度），180° 表示從正左方開始逆時針繪製（0° 為正右方）
plt.show()

# %%
# 步驟 1:匯入 matplotlib.pyplot,取別名為 plt


# 步驟 2:建立飲料名稱的串列(奶茶、紅茶、綠茶、咖啡)


# 步驟 3:建立各飲料銷售杯數的串列(50、25、35、40)


# 步驟 4:建立四種顏色的串列


# 步驟 5:建立 explode 串列,讓奶茶那一塊突出 0.2,其餘為 0


# 步驟 6:建立 figure


# 步驟 7:用 add_subplot() 建立 axes


# 步驟 8:呼叫 axes.pie(),傳入杯數,並設定 labels、colors、explode、
#         startangle=90、shadow=True、autopct='%1.1f%%'


# 步驟 9:用 plt.show() 顯示圖表

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 若要顯示中文標籤，將字型設定為系統中文字型
font_path = r"C:\Windows\Fonts\msjh.ttc"
font_prop = fm.FontProperties(fname=font_path)
plt.rcParams['font.family'] = font_prop.get_name()
plt.rcParams['axes.unicode_minus'] = False

labels = ["奶茶", "紅茶", "綠茶", "咖啡"] #奶茶、紅茶、綠茶、咖啡
values = [50, 25, 35, 40] #50、25、35、40
colors = ['purple', 'pink', 'gray', 'darkblue']

figure = plt.figure()
axes = figure.add_subplot()
axes.pie(values, #每個扇區的數值資料（list / array）
         labels=labels, #每個扇區的標籤文字
         colors=colors, #每個扇區的自訂顏色
         explode=[0.2, 0, 0, 0], #將第一個扇區「拉出」0.2 倍半徑距離，用來強調某個區塊
         shadow=True, #	在圓餅圖後方加上陰影，增加立體感
         autopct="%1.1f%%", #在扇區內部顯示百分比，格式為整數 2 位、小數 1 位（如 12.3%）
         startangle=90) #	第一個扇區的起始角度（度），180° 表示從正左方開始逆時針繪製（0° 為正右方）
plt.show()
