# %%
#引數值的呼叫，必須依照說明書的順序來呼叫
try:
	with open("student.txt", "r", encoding="utf-8") as file:
			data = file.read()
			print(data)
except Exception as e: #e代表錯誤訊息
	print("發生錯誤:", e)
# Out:
# 王小明
# 陳大華
# 林美玲

# %%
try:
	with open(file = "student.txt") as file:
			data = file.read()
			print(data)
except Exception as e: #e代表錯誤訊息
	print("發生錯誤:", e)
# Out:
# 發生錯誤: 'cp950' codec can't decode byte 0xe7 in position 0: illegal multibyte sequence

# %%
# open("student.txt") 引數值的呼叫,必需依順序

try:
	with open("student.txt",'r',-1,'utf-8') as file:
			data = file.read()
			print(data)
except Exception as e:
	print("發生錯誤:", e)
# Out:
# 王小明
# 陳大華
# 林美玲

# %%
# open(file="student.txt") 引數名稱的呼叫,可以不依順序,只要依照名

try:
	with open(file="student.txt",encoding="utf-8") as file:
			data = file.read()
			print(data)
except Exception as e:
	print("發生錯誤:", e)
# Out:
# 王小明
# 陳大華
# 林美玲

# %%
# open(file="student.txt") 混合的呼叫,可以不依順序,只要依照名

try:
	with open("student.txt",encoding="utf-8",mode="r") as file:
			data = file.read()
			print(data)
except Exception as e:
	print("發生錯誤:", e)
# Out:
# 王小明
# 陳大華
# 林美玲

# %%
open("student.txt","r",-1,"utf-8")
# Out:
# <_io.TextIOWrapper name='student.txt' mode='r' encoding='utf-8'>

# %%
students = [68,95,78,65,92]
print(type(students))
# Out:
# <class 'list'>

# %%
file = open("student.txt","r",encoding="utf-8")
print(file.name)
print(file.mode)
print(file.closed)
print(file.encoding)
print(file.read())
file.close() #print(file.close()) 沒有輸出不用print,因為close()沒有回傳值
# Out:
# student.txt
# r
# False
# utf-8
# 王小明
# 陳大華
# 林美玲
